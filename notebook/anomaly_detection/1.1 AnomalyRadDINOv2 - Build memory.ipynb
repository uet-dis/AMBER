# %%
USR_NAME = 'thebeo2004'
REPO_NAME = 'AMBER'

# !git clone https://{USR_NAME}:{GITHUB_PAT}@github.com/{USR_NAME}/{REPO_NAME}.git
# %cd /kaggle/working/{REPO_NAME}
# !git checkout cascade-anomaly
# !git submodule update --init --recursive
# Out:
# Cloning into 'SAGE'...
# remote: Enumerating objects: 745, done.
# remote: Total 745 (delta 0), reused 0 (delta 0), pack-reused 745 (from 1)
# Receiving objects: 100% (745/745), 52.40 MiB | 36.08 MiB/s, done.
# Resolving deltas: 100% (406/406), done.
# /kaggle/working/SAGE
# Branch 'cascade-anomaly' set up to track remote branch 'cascade-anomaly' from 'origin'.
# Switched to a new branch 'cascade-anomaly'
# Submodule 'anomalib' (https://github.com/thebeo2004/anomalib.git) registered for path 'anomalib'
# Submodule 'detrex' (https://github.com/thebeo2004/detrex.git) registered for path 'detrex'
# Cloning into '/kaggle/working/SAGE/anomalib'...
# Cloning into '/kaggle/working/SAGE/detrex'...
# Submodule path 'anomalib': checked out 'c681709a989701e72fee128ad80443be4d776b47'
# Submodule path 'detrex': checked out '58a09c6fbe022077f6e26d8a8eda25f142092f21'
# Submodule 'detectron2' (https://github.com/thebeo2004/detectron2.git) registered for path 'detrex/detectron2'
# Cloning into '/kaggle/working/SAGE/detrex/detectron2'...
# Submodule path 'detrex/detectron2': checked out 'dca70bb496af02814d4876d7036b9ba846bafe6a'

# %%
# !uv pip install --system -q -r pyproject.toml
# !pip install -q ninja
# %cd detrex/detectron2
# !uv pip install --system -q -e . --no-build-isolation
# %cd ..
# !uv pip install --system -q -e . --no-build-isolation
# %cd /kaggle/working/{REPO_NAME}/anomalib
# !uv pip install --system -q -e .
# Out:
# /kaggle/working/SAGE/detrex/detectron2
# /kaggle/working/SAGE/detrex
# /kaggle/working/SAGE/anomalib

# %%
REPO_NAME = 'AMBER'
# %cd /kaggle/working/{REPO_NAME}
# !python src/memory_bank/build_memory.py \
    --raddino_checkpoint_path /kaggle/input/models/thebeo182004/raddino-vitb14-topad16/pytorch/default/1/rad_dino_vitb14_detrex_ready.pth \
    --train_normal_data_dir /kaggle/input/datasets/thebeo182004/medanomaly-vindrcxr/medi_anomaly/train \
    --save_path /kaggle/working/raddino_memory_bank.pt \
    --subsampling_ratio 0.1 \
    --normal_num 500 \
    --batch_size 128 \
    --use_aamb \
    --anatomy_dir /kaggle/input/notebooks/thebeo182004/medianomaly-vindrcxr-anatomy-maps/medianomaly/train
# Out:
# /kaggle/working/SAGE
# /usr/local/lib/python3.12/dist-packages/FrEIA/modules/all_in_one_block.py:66: SyntaxWarning: invalid escape sequence '\m'
#   Initial value for the global affine scaling :math:`s_\mathrm{global}`.
# /kaggle/working/SAGE/detrex/detrex/layers/dcn_v3.py:23: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /kaggle/working/SAGE/detrex/detrex/layers/dcn_v3.py:52: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /kaggle/working/SAGE/detrex/detrex/modeling/backbone/timm_backbone.py:101: UserWarning: Using both features_only and checkpoint_path may cause error in timm. See https://github.com/rwightman/pytorch-image-models/issues/488
#   warnings.warn(
# [05/08 02:09:31 timm backbone]: backbone out_indices: (11,)
# [05/08 02:09:31 timm backbone]: backbone out_channels: [768]
# [05/08 02:09:31 timm backbone]: backbone out_strides: [16]
# Using 2 GPUs for AAMB construction.
# [V2] Anatomical-Aware Memory Bank Construction Started...
#   0%|                                                     | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/albumentations/core/composition.py:331: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# /usr/local/lib/python3.12/dist-packages/albumentations/core/composition.py:331: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# /usr/local/lib/python3.12/dist-packages/albumentations/core/composition.py:331: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# /usr/local/lib/python3.12/dist-packages/albumentations/core/composition.py:331: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# 100%|█████████████████████████████████████████████| 4/4 [02:21<00:00, 35.33s/it]
# Multi-organ Extraction Completed.
# Starting independent Coreset Subsampling for Sub-Banks...
# [Organ Clavicle] Subsampling from 70204 patches...
# Selecting Coreset Indices.: 100%|██████████| 7019/7019 [00:08<00:00, 871.99it/s]
# [Organ Clavicle] Sub-bank created with shape: torch.Size([7020, 768])
# [Organ Lung] Subsampling from 678697 patches...
# Selecting Coreset Indices.: 100%|█████████| 67868/67868 [14:28<00:00, 78.12it/s]
# [Organ Lung] Sub-bank created with shape: torch.Size([67869, 768])
# [Organ Heart] Subsampling from 162154 patches...
# Selecting Coreset Indices.: 100%|████████| 16214/16214 [00:42<00:00, 381.27it/s]
# [Organ Heart] Sub-bank created with shape: torch.Size([16215, 768])
# [Organ Facies Diaphragmatica] Subsampling from 479703 patches...
# Selecting Coreset Indices.: 100%|████████| 47969/47969 [06:45<00:00, 118.38it/s]
# [Organ Facies Diaphragmatica] Sub-bank created with shape: torch.Size([47970, 768])
# [Organ Mediastinum] Subsampling from 98422 patches...
# Selecting Coreset Indices.: 100%|██████████| 9841/9841 [00:15<00:00, 633.53it/s]
# [Organ Mediastinum] Sub-bank created with shape: torch.Size([9842, 768])
# Saved AAMB, including full of sub-banks at: /kaggle/working/raddino_memory_bank.pt
# Organ Clavicle coreset shape: torch.Size([7020, 768])
# Organ Lung coreset shape: torch.Size([67869, 768])
# Organ Heart coreset shape: torch.Size([16215, 768])
# Organ Facies Diaphragmatica coreset shape: torch.Size([47970, 768])
# Organ Mediastinum coreset shape: torch.Size([9842, 768])
